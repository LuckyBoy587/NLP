# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
df = pd.read_csv("ML471_S1_Datafile_Concept.csv")
df["DATE"] = pd.to_datetime(df["DATE"])
df.head()
# Out:
#         DATE  Consumption  Festivals/Special_events
# 0 1988-01-01     107.5052                         6
# 1 1988-02-01     105.6720                         1
# 2 1988-03-01      97.4502                         1
# 3 1988-04-01      92.4714                         1
# 4 1988-05-01      90.3151                         1

# %%
years = df["DATE"].dt.year.unique()
plt.plot(df["DATE"], df["Consumption"])
ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator(4))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
plt.show()

# %%
sns.barplot(data=df, x="Festivals/Special_events", y="Consumption")
# Out:
# <Axes: xlabel='Festivals/Special_events', ylabel='Consumption'>

# %%
sns.barplot(data=df, x="Festivals/Special_events", y="Consumption")
# Out:
# <Axes: xlabel='Festivals/Special_events', ylabel='Consumption'>
